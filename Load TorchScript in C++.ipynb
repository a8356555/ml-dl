# %% [markdown]
# 将 PyTorch 模型转换为 Torch 脚本
# * 方法1 通過跟蹤
# * 方法2 通過註釋

# %%
# 方法一
import torch, torchvision

model = torchvision.models.resnet18()

example = torch.rand(1, 3, 224, 224)

traced_script_module = torch.jit.trace(model, example)

# %%
# 方法二
